# %%
pip install python-telegram-bot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import telebot
import logging
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters, CallbackQueryHandler, CallbackContext
from telegram import InlineKeyboardButton, InlineKeyboardMarkup, Update
TOKEN = '5125597486:AAGcmWCNqGclaxArsRW7_Y21FiqE6KleVzU'
updater = Updater(TOKEN, use_context=True)
dp = updater.dispatcher
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

bot = telebot.TeleBot(TOKEN)

@bot.message_handler(content_types=['text'])
def get_text_messages(message):
    if message.text == "/start":
        bot.send_message(message.from_user.id, "дарова, крыса!\nвот те лист функций:\n/start - начать\n/hello - приветствую\n/shutka - юмор\n/pravda - узнай о себе правду\n/zodiac - астрологическое наставление")
    elif message.text == "/hello":
        bot.send_message(message.from_user.id, "добро пожаловать в крысиный чат")
    elif message.text == "/shutka":
        bot.send_message(message.from_user.id, "хочешь шутку?")
    elif message.text == "да":
        bot.send_message(message.from_user.id, 'пизда')
    elif message.text == "Да":
        bot.send_message(message.from_user.id, 'пизда')
    elif message.text == "Да.":
        bot.send_message(message.from_user.id, 'пизда')
    elif message.text == "Нет":
        bot.send_message(message.from_user.id, 'ну и не надо')
    elif message.text == "Нет.":
        bot.send_message(message.from_user.id, 'ну и не надо')
    elif message.text == "нет":
        bot.send_message(message.from_user.id, 'ну и не надо')
    elif message.text == "/pravda":
        bot.send_message(message.from_user.id, 'ты крыса')
        
    elif message.text == "/zodiac":
        bot.send_message(message.from_user.id, 'кто ты по гороскопу?')
        
    elif message.text == "Телец":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша (не маме)')
    elif message.text == "Телец.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша (не маме)')
    elif message.text == "телец":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша (не маме)')
    elif message.text == "Стрелец":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Стрелец.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "стрелец":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Лев":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Лев.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "лев":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Весы":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Весы.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "весы":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Дева":
        bot.send_message(message.from_user.id, 'исчезни')
    elif message.text == "дева":
        bot.send_message(message.from_user.id, 'исчезни')
    elif message.text == "Дева.":
        bot.send_message(message.from_user.id, 'исчезни')   
    elif message.text == "Рак":
        bot.send_message(message.from_user.id, "ты алмаз")
    elif message.text == "рак":
        bot.send_message(message.from_user.id, 'ты алмаз')
    elif message.text == "Рак":
        bot.send_message(message.from_user.id, 'ты алмаз')
    elif message.text == "скорпион":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Скорпион":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')   
    elif message.text == "Скорпион.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Близнецы":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Близнецы.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')   
    elif message.text == "близнецы":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Водолей":
        bot.send_message(message.from_user.id, 'у вас всё норм вроде')
    elif message.text == "Водолей.":
        bot.send_message(message.from_user.id, 'у вас всё норм вроде')
    elif message.text == "водолей":
        bot.send_message(message.from_user.id, 'у вас всё норм вроде')
    elif message.text == "козерог":
        bot.send_message(message.from_user.id, 'у вас всё норм вроде')
    elif message.text == "Козерог":
        bot.send_message(message.from_user.id, 'у вас всё норм вроде')
    elif message.text == "Козерог.":
        bot.send_message(message.from_user.id, 'у вас всё норм вроде')
    elif message.text == "Рыбы.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Рыбы":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "рыбы":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Овен":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "Овен.":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    elif message.text == "овен":
        bot.send_message(message.from_user.id, 'стоит дать денег знакомой по имени Саша')
    else:
        bot.send_message(message.from_user.id, "нормально напиши")

bot.polling(none_stop=True)
# Out:
# 2022-04-07 20:28:54,846 - telegram.ext.dispatcher - DEBUG - Setting singleton dispatcher as None
# 2022-04-07 20:28:54,858 - urllib3.connectionpool - DEBUG - Starting new HTTPS connection (1): api.telegram.org:443
# 2022-04-07 20:28:58,761 - urllib3.connectionpool - DEBUG - https://api.telegram.org:443 "GET /bot5125597486:AAGcmWCNqGclaxArsRW7_Y21FiqE6KleVzU/getUpdates?offset=1&timeout=20 HTTP/1.1" 409 143
# 2022-04-07 20:28:58,764 (__init__.py:688 MainThread) ERROR - TeleBot: "A request to the Telegram API was unsuccessful. Error code: 409. Description: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"
# 2022-04-07 20:28:58,764 - TeleBot - ERROR - A request to the Telegram API was unsuccessful. Error code: 409. Description: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# ...
